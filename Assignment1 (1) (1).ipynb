# %%
#Import the csv library
import csv

# %%
#Open the CSV file
with open('C:\\Users\\MVSR\\Desktop\\Dataset.csv','r')as csv_file:
    ###Use the csv.reader object to read the CSV file.
    csv_reader=csv.reader(csv_file)
    ### Extract the field names
    header = next(csv_reader)
# Extract the field names

# %%
#Load the data from a CSV file into memory using the CSV module.
#Open the CSV file
with open('C:\\Users\\MVSR\\Desktop\\Dataset.csv','r',encoding='utf8')as csv_file:
    #Use the csv.reader object to read the CSV file.
    csv_reader=csv.reader(csv_file)
    
   #Retrieve a name of listing, host_name, description, host_location, and the date the host was created for an individual host by host_id
  
    #To retrieve the data by host Id
    id = input("Enter host ID")
#gives us al list of everything in col 0
    for row in csv_reader:
        if row[0] == id:
            print("Name of listing:","        ",row[1])
            print("Host Name:","              ",row[3])
            print("Discription:","             ",row[2])
            print("Host Location:","           ",row[5])
            print("Date the host was created:","  ",row[4])
            break
# Out:
# Enter host ID586671
# Name of listing:          DOUBLE ROOM NEAR CENTRAL LONDON
# Host Name:                Joe
# ...

# %%
 #Load the data from a CSV file into memory using the CSV module.
#Open the CSV file
with open('C:\\Users\\MVSR\\Desktop\\Dataset.csv','r',encoding='utf8')as csv_file:
    #Use the csv.reader object to read the CSV file.
    csv_reader=csv.reader(csv_file)
    ###Retrieve host_name, property_type, price, minimum_nights, and maximum_nights of all Airbnb listing for a specified location
    ###To retrieve the data by specified location
    
    location  = input("Enter the location")
    ###Gives us a list of location in col 5
    count=0
    for row in csv_reader:
        if row[5] == location:
            count+=1;
            print("Details  ",count,"  for same location for ")
            print("Host Name:","        ",row[3])
            print("Property type","     ",row[13])
            print("Price:","             ",row[20])
            print("Minimum nights:","    ",row[21])
            print("Maximum nights:","    ",row[22])
# Out:
# Enter the locationRichmond
# Details   1   for same location for
# Host Name:          Geert
# Property type       townhouse
# Price:               245
# Minimum nights:      3
# Maximum nights:      22
# Details   2   for same location for
# Host Name:          Edward
# Property type       townhouse
# Price:               55
# Minimum nights:      1
# Maximum nights:      1125
# Details   3   for same location for
# Host Name:          Joanna
# Property type       home
# Price:               232
# Minimum nights:      4
# Maximum nights:      1125
# Details   4   for same location for
# Host Name:          Colleen
# Property type       loft
# Price:               121
# Minimum nights:      2
# Maximum nights:      1125
# Details   5   for same location for
# Host Name:          Eleanor
# Property type       home
# Price:               44
# Minimum nights:      1
# Maximum nights:      3
# Details   6   for same location for
# Host Name:          Paul
# ...

# %%
  ###Retrieve room_type, accommodates, bathrooms, bedroom, and beds of all Airbnb listing for a specified property type
with open('C:\\Users\\MVSR\\Desktop\\Dataset.csv','r',encoding='utf8')as csv_file:
    ###Use the csv.reader object to read the CSV file.
    csv_reader=csv.reader(csv_file)
    value=0
    property = input("Enter property type:  ")   
    count=0
    for row in csv_reader:
        if row[13] == property:
            count=count+1;
            print("Details  ",count,"  for same property type  ")
            print("Room type:","    ",row[14])
            print("Accommodates:"," ",row[15])
            print("Bathrooms:","    ",row[16])
            print("Bedroom:","      ",row[17])
            print("Beds:","          ",row[18])
# Out:
# Enter property type:  townhouse
# Details   1   for same property type
# Room type:      home/apt
# Accommodates:   2
# Bathrooms:      1.5 baths
# Bedroom:        1
# Beds:            1
# Details   2   for same property type
# Room type:      Private room
# Accommodates:   1
# Bathrooms:      1 shared bath
# Bedroom:        1
# Beds:            1
# Details   3   for same property type
# Room type:      home/apt
# Accommodates:   5
# Bathrooms:      1.5 baths
# Bedroom:        3
# Beds:            3
# Details   4   for same property type
# Room type:      Private room
# Accommodates:   3
# Bathrooms:      1.5 baths
# Bedroom:        1
# Beds:            1
# Details   5   for same property type
# Room type:      home/apt
# Accommodates:   6
# Bathrooms:      2.5 baths
# Bedroom:        3
# Beds:            3
# Details   6   for same property type
# Room type:      Private room
# Accommodates:   2
# Bathrooms:      1 private bath
# Bedroom:        1
# Beds:            2
# ...

# %%
###Retrieve room_type, accommodates, bathrooms, bedroom, and beds of all Airbnb listing for a specified property type
with open('C:\\Users\\MVSR\\Desktop\\Dataset.csv','r',encoding='utf8')as csv_file:
    ###Use the csv.reader object to read the CSV file.
    csv_reader=csv.reader(csv_file)
    #Retrieve specific columns of your choice related to an individual host by location
    host = input("Enter host name :  ")
    count=0
    for row in csv_reader:
        if row[3] == host:
            count=count+1;
            print("Details  ",count,"  for same host name :  ")
            print("Name:","    ",row[1])
            print("Host Response:"," ",row[6])
            print("Room Type:","    ",row[15])
# Out:
# Enter host name :  Joe
# Details   1   for same host name :
# Name:      Battersea live/work artist house, garden communal
# Host Response:   within a day
# Room Type:      2
# Details   2   for same host name :
# Name:      DOUBLE ROOM NEAR CENTRAL LONDON
# Host Response:   within a day
# Room Type:      1
# Details   3   for same host name :
# Name:      SINGLE ROOM  NEAR CENTRAL LONDON
# Host Response:   within a day
# Room Type:      1
# Details   4   for same host name :
# Name:      HAYES, MIDDLESEX
# Host Response:   within a few hours
# Room Type:      1
# Details   5   for same host name :
# Name:      Large, spacious 1 bed and breakfastroom flat
# Host Response:   within an hour
# Room Type:      1
# Details   6   for same host name :
# Name:      Characterful Hackney Garden Flat with resident Cat
# Host Response:   within a day
# Room Type:      2
# Details   7   for same host name :
# Name:      2 bed and breakfast Broadway Market apt. Bright & very quiet!
# ...
